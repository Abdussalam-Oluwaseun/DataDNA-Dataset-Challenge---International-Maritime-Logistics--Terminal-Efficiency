# %%
import pandas as pd

file_path = "/Users/hello/Downloads/DataDNA Dataset Challenge - International Maritime Logistics  Terminal Efficiency/data/International Maritime Logistics Terminal Efficiency.xlsx"

xls = pd.ExcelFile(file_path)
print(xls.sheet_names)
# Out:
# ['Sheet1', 'fact_cargo_movements', 'fact_cargo_movements (2)', 'dim_vessel', 'dim_terminal', 'dim_terminal (2)', 'dim_time']
